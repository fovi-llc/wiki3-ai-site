# %%
hello
# Out:
# Hello there! 😊
#
# It's nice to meet you.  How can I help you today?  Do you have any questions, need information, or just want to chat?
#
# Let me know what's on your mind!

# %%
%chat status
# Out:
# Active session:
#   Provider: built-in-ai
#   Model: prompt-api

# %% [markdown]
# * A blank key, either as --key to the provider magic or the key magic will pop up a modal password dialog.

# %%
%chat provider google
%chat model gemini-2.5-flash
%chat key
# Out:
# Provider: Google
# Model: gemini-2.5-flash
# API key set.

# %%
hello
# Out:
# Hello! How can I help you today?

# %%
what are you
# Out:
# I am a large language model, trained by Google.
#
# My purpose is to assist users by providing information, generating text, answering questions, translating languages, summarizing complex topics, and engaging in creative writing.
#
# I don't have personal opinions, emotions, consciousness, or a physical body. I operate by processing the text you provide and generating responses based on the vast amount of data I was trained on. My goal is to be helpful and informative.

# %%
%chat provider openai
%chat model gpt-5-mini
%chat key
# Out:
# Provider: OpenAI
# Model: gpt-5-mini
# API key set.

# %%
what are you
# Out:
# I'm ChatGPT — an AI language model created by OpenAI. Briefly:
#
# - What I am: a large language model (LLM) that generates text by predicting patterns from training data.
# - What I can do: answer questions, explain concepts, help with writing and editing, generate code, create summaries, brainstorm, tutor, translate, and more.
# - What I can’t do: perceive the real world, have personal experiences or feelings, or access private data unless you provide it during the chat. I also don’t have real-time web access unless a browsing tool is enabled.
# - Limits: my knowledge is current up to June 2024, and I can make mistakes or produce misleading information — always verify critical facts.
# - Privacy: I don’t retain memory between sessions unless a system built by the app stores it; don’t share sensitive personal details.
#
# How can I help you today?

# %%
%chat provider anthropic --key
%chat model claude-haiku-4-5
# Out:
# Provider: Anthropic
# Model: claude-haiku-4-5

# %%
What are you?

# %% [markdown]
# Access to fetch at 'https://api.anthropic.com/v1/messages' from origin 'https://wiki3.ai' has been blocked by CORS policy: Response to preflight request doesn't pass access control check: No 'Access-Control-Allow-Origin' header is present on the requested resource.
